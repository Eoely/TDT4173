# %%
import pandas
from sklearn import model_selection
from sklearn.ensemble import AdaBoostClassifier
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = pandas.read_csv('pima-indians-diabetes.csv', names=names)

# %%
dataframe
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 0       6   148    72    35     0  33.6  0.627   50      1
# 1       1    85    66    29     0  26.6  0.351   31      0
# 2       8   183    64     0     0  23.3  0.672   32      1
# 3       1    89    66    23    94  28.1  0.167   21      0
# 4       0   137    40    35   168  43.1  2.288   33      1
# ..    ...   ...   ...   ...   ...   ...    ...  ...    ...
# 763    10   101    76    48   180  32.9  0.171   63      0
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %%
array = dataframe.values
X = array[:,0:8]
Y = array[:,8]
seed = 7
num_trees = 30
kfold = model_selection.KFold(n_splits=10, random_state=seed)
model = AdaBoostClassifier(n_estimators=num_trees, random_state=seed)
results = model_selection.cross_val_score(model, X, Y, cv=kfold)
print(results.mean())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 6
#       4 seed = 7
#       5 num_trees = 30
# ----> 6 kfold = model_selection.KFold(n_splits=10, random_state=seed)
#       7 model = AdaBoostClassifier(n_estimators=num_trees, random_state=seed)
#       8 results = model_selection.cross_val_score(model, X, Y, cv=kfold)
#
# File ~/school/tdt4173/tdt4173_venv/lib/python3.13/site-packages/sklearn/model_selection/_split.py:514, in KFold.__init__(self, n_splits, shuffle, random_state)
#     513 def __init__(self, n_splits=5, *, shuffle=False, random_state=None):
# --> 514     super().__init__(n_splits=n_splits, shuffle=shuffle, random_state=random_state)
#
# File ~/school/tdt4173/tdt4173_venv/lib/python3.13/site-packages/sklearn/model_selection/_split.py:365, in _BaseKFold.__init__(self, n_splits, shuffle, random_state)
#     362     raise TypeError("shuffle must be True or False; got {0}".format(shuffle))
#     364 if not shuffle and random_state is not None:  # None is the default
# --> 365     raise ValueError(
#     366         (
#     367             "Setting a random_state has no effect since shuffle is "
#     368             "False. You should leave "
#     369             "random_state to its default (None), or set shuffle=True."
#     370         ),
#     371     )
#     373 self.n_splits = n_splits
#     374 self.shuffle = shuffle
#
# ValueError: Setting a random_state has no effect since shuffle is False. You should leave random_state to its default (None), or set shuffle=True.
